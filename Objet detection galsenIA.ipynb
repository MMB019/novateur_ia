# %%
# !pip3 install torch torchvision torchaudio

# %%
#!git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
# !pip install opencv-python

# %%
import torch 
import matplotlib.pyplot as plt 
import numpy as np 
import cv2

# %%
model=torch.hub.load("ultralytics/yolov5","yolov5s")
# Out:
# Using cache found in C:\Users\a846864/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-10-15 Python-3.9.7 torch-1.11.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img = 'https://www.dakaractu.com/photo/art/default/3405294-4896859.jpg'  # or file, Path, PIL, OpenCV, numpy, list


results = model(img)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# image 1/1: 525x700 8 persons, 33 cars, 1 motorcycle, 1 horse, 1 chair
# Speed: 4944.3ms pre-process, 872.0ms inference, 9.0ms NMS per image at shape (1, 3, 480, 640)

# %%
print(results.render())
# Out:
# [array([[[ 78,  81,  52],
#         [ 75,  75,  49],
#         [ 78,  74,  49],
#         ...,
#         [ 70,  51,  47],
#         [ 71,  52,  46],
#         [ 71,  52,  46]],
#
#        [[ 71,  73,  51],
#         [ 75,  74,  53],
#         [ 81,  76,  56],
#         ...,
#         [ 75,  54,  49],
#         [ 75,  54,  49],
#         [ 74,  55,  48]],
#
#        [[ 70,  71,  55],
#         [ 75,  73,  58],
#         [ 80,  74,  60],
#         ...,
#         [ 76,  52,  48],
#         [ 77,  53,  49],
#         [ 75,  55,  48]],
#
#        ...,
#
#        [[ 65,  42,  48],
#         [ 70,  47,  53],
#         [ 72,  51,  56],
#         ...,
#         [123, 110, 104],
#         [123, 110, 102],
#         [123, 110, 102]],
#
#        [[ 72,  47,  53],
#         [ 75,  50,  56],
#         [ 76,  53,  59],
#         ...,
#         [124, 113, 107],
#         [124, 113, 107],
#         [125, 114, 108]],
#
#        [[ 75,  48,  57],
#         [ 76,  51,  57],
#         [ 81,  56,  62],
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    rect,frame=cap.read()
    results=model(frame)
    
    cv2.imshow("YOLOV",np.squeeze(results.render()))
    if cv2.waitKey(10)& 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import uuid #unique identifier
import os
import time

# %%
# !dir
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est A4AC-61C4
#
#  R‚pertoire de C:\Users\a846864\Documents\conf_samedi\galsenIA
#
# 01/12/2022  20:19    <DIR>          .
# 01/12/2022  20:19    <DIR>          ..
# 13/10/2022  23:07    <DIR>          .ipynb_checkpoints
# 01/12/2022  21:53    <DIR>          data
# 14/10/2022  01:14    <DIR>          mon_data_moi
# 01/12/2022  20:19         1ÿ133ÿ038 Objet detection galsenIA.ipynb
# 13/10/2022  23:19    <DIR>          runs
# 14/10/2022  03:11    <DIR>          yolov5
# 13/10/2022  23:16        14ÿ808ÿ437 yolov5s.pt
#                2 fichier(s)       15ÿ941ÿ475 octets
#                7 R‚p(s)  40ÿ302ÿ505ÿ984 octets libres

# %%
import shutil

# %%
for img_d in os.listdir(os.path.join("data","yolo")):
    for img_p in os.listdir(os.path.join("data","yolo",img_d)):
        code_g=str(uuid.uuid1())
        if img_p.endswith(".txt"):
            os.rename(os.path.join("data","yolo",img_d,img_p),os.path.join("data","labels","novateur"+'.'+code_g+'.'+img_p.split(".")[1]))
        
        else:
            os.rename(os.path.join("data","yolo",img_d,img_p),os.path.join("data","images","novateur"+'.'+code_g+'.'+img_p.split(".")[1]))

# %%
for img_d in os.listdir(os.path.join("data","yolo")):
    for img_p in os.listdir(os.path.join("data","yolo",img_d)):
        code_g=str(uuid.uuid1())
        if img_p.endswith(".txt"):
  
            shutil.copy(os.path.join("data","yolo",img_d,img_p), os.path.join("data","labels"))
        else:
          
            shutil.copy(os.path.join("data","yolo",img_d,img_p), os.path.join("data","images"))

# %%
for img_d in os.listdir(os.path.join("yolo")):
    for img_path in os.listdir(os.path.join("yolo",img_d)):
        if im
# Out:
#   File "C:\Users\a846864\AppData\Local\Temp/ipykernel_19036/3980561061.py", line 1
#     for img_d in os.listdir(os.path.join("yolo")):
#                                                   ^
# IndentationError: expected an indented block

# %%
IMAGE_PATH=os.path.join("mon_data_moi")
print(os.listdir(IMAGE_PATH))
# Out:
# ['espadons', 'hippocampe', 'poisson_lune']

# %%
for rep in os.listdir(IMAGE_PATH):
    print(rep)
    
    for img_path in os.listdir(os.path.join(IMAGE_PATH,rep)):
        #print(img_path.split(".")[1])
        #print(os.path.join(IMAGE_PATH,rep,img_path))
        #print(img_path)
        os.rename(os.path.join(IMAGE_PATH,rep,img_path),rep+'.'+str(uuid.uuid1())+'.'+img_path.split(".")[1])
# Out:
# espadons
# hippocampe
# poisson_lune

# %%
# !dir
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est A4AC-61C4
#
#  R‚pertoire de C:\Users\a846864\Documents\conf_samedi\galsenIA
#
# 01/12/2022  23:18    <DIR>          .
# 01/12/2022  23:18    <DIR>          ..
# 13/10/2022  23:07    <DIR>          .ipynb_checkpoints
# 01/12/2022  22:50    <DIR>          data
# 14/10/2022  01:14    <DIR>          mon_data_moi
# 01/12/2022  23:18         1ÿ134ÿ242 Objet detection galsenIA.ipynb
# 13/10/2022  23:19    <DIR>          runs
# 14/10/2022  03:11    <DIR>          yolov5
# 13/10/2022  23:16        14ÿ808ÿ437 yolov5s.pt
#                2 fichier(s)       15ÿ942ÿ679 octets
#                7 R‚p(s)  39ÿ988ÿ989ÿ952 octets libres

# %%
#!pip install pyqt5 lxml --upgrade
#!cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# %cd yolov5
# Out:
# C:\Users\a846864\Documents\conf_samedi\galsenIA\yolov5

# %%
# !dir
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est A4AC-61C4
#
#  R‚pertoire de C:\Users\a846864\Documents\conf_samedi\galsenIA\yolov5
#
# 14/10/2022  03:11    <DIR>          .
# 14/10/2022  03:11    <DIR>          ..
# 13/10/2022  23:11             3ÿ923 .dockerignore
# 13/10/2022  23:11                77 .gitattributes
# 13/10/2022  23:11    <DIR>          .github
# 13/10/2022  23:11             4ÿ238 .gitignore
# 13/10/2022  23:11             1ÿ619 .pre-commit-config.yaml
# 13/10/2022  23:11             8ÿ005 benchmarks.py
# 13/10/2022  23:11    <DIR>          classify
# 13/10/2022  23:11             5ÿ087 CONTRIBUTING.md
# 13/10/2022  23:11    <DIR>          data
# 14/10/2022  03:07               293 dataset.yml
# 13/10/2022  23:11            14ÿ234 detect.py
# 13/10/2022  23:11            30ÿ646 export.py
# 13/10/2022  23:11             7ÿ891 hubconf.py
# 13/10/2022  23:11            35ÿ801 LICENSE
# 14/10/2022  03:10    <DIR>          models
# ...

# %%
# !python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 93 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5  v6.2-193-g15b7565 Python-3.9.7 torch-1.11.0 CPU
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\a846864/.cache\torch\hub\master.zip
# YOLOv5  2022-10-15 Python-3.9.7 torch-1.11.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7058671 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
# !dir
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num‚ro de s‚rie du volume est A4AC-61C4
#
#  R‚pertoire de C:\Users\a846864\Documents\conf_samedi\galsenIA
#
# 15/10/2022  17:13    <DIR>          .
# 15/10/2022  17:13    <DIR>          ..
# 13/10/2022  23:07    <DIR>          .ipynb_checkpoints
# 14/10/2022  03:12    <DIR>          data
# 14/10/2022  01:14    <DIR>          mon_data_moi
# 15/10/2022  17:13           946ÿ396 Objet detection galsenIA.ipynb
# 13/10/2022  23:19    <DIR>          runs
# 14/10/2022  03:11    <DIR>          yolov5
# 13/10/2022  23:16        14ÿ808ÿ437 yolov5s.pt
#                2 fichier(s)       15ÿ754ÿ833 octets
#                7 R‚p(s)  23ÿ872ÿ856ÿ064 octets libres

# %%
import os

# %%
img_dir=os.path.join("data","images")
img_dir
# Out:
# 'data\\images'

# %%
img_test=os.listdir(img_dir)[30]
img_test
img_test_path=os.path.join("data","images",img_test)

# %%
result_test=model(os.path.join("data","images","animaux-marins.jpg"))

# %%
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.imshow(np.squeeze(result_test.render()))
plt.show()
